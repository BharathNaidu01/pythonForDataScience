# %%
import pandas as pd

df = pd.read_csv("F:\datasets\country_vaccinations.csv")

# %%
df.head(4)
# Out:
#      country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Argentina      ARG  2020-12-29               700.0                NaN
# 1  Argentina      ARG  2020-12-30                 NaN                NaN
# 2  Argentina      ARG  2020-12-31             32013.0                NaN
# 3  Argentina      ARG  2021-01-01                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN             15656.0
# 2                      NaN                     NaN             15656.0
# 3                      NaN                     NaN             11070.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                            0.00                            NaN
# 1                             NaN                            NaN
# ...

# %%
df.drop(columns=["iso_code"])
# Out:
#         country        date  total_vaccinations  people_vaccinated  \
# 0     Argentina  2020-12-29               700.0                NaN
# 1     Argentina  2020-12-30                 NaN                NaN
# 2     Argentina  2020-12-31             32013.0                NaN
# 3     Argentina  2021-01-01                 NaN                NaN
# 4     Argentina  2021-01-02                 NaN                NaN
# ...         ...         ...                 ...                ...
# 1318      Wales  2021-01-17            151938.0           151737.0
# 1319      Wales  2021-01-18            162197.0           161932.0
# 1320      Wales  2021-01-19            176186.0           175816.0
# 1321      Wales  2021-01-20            190831.0           190435.0
# 1322      Wales  2021-01-21            212732.0           212317.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                         NaN                     NaN                 NaN
# ...
